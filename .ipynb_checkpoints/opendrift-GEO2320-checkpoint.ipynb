# %%
# %matplotlib inline

# %% [markdown]
# # Examples of oceanic drift
#
# *2023-09-13, kaihc@met.no*
#
# ## Cases:
#
# 1. No effect of turbulent mixing,
#    i.e. constant depth for all particles throughout.
# 1. With turbulent mixing,
#    i.e. all particles moves freely in the vertical with **no buoyancy**.
# 1. With turbulent mixing, but
#    now with an additional **terminal rise velocity added**.

# %%
import numpy as np
from datetime import datetime, timedelta
from opendrift.readers import reader_netCDF_CF_generic
from opendrift.readers import reader_ROMS_native, reader_netCDF_CF_generic
from opendrift.models.oceandrift import OceanDrift

# %%
# Initialise cases
loglev = 20 # Set loglevel to 0 for debug information
o1 = OceanDrift(loglevel=loglev)  
o2 = OceanDrift(loglevel=loglev) 
o3 = OceanDrift(loglevel=loglev) 


# Creating and adding reader for Norkyst current dataset and WAM wave data set
norkyst = reader_netCDF_CF_generic.Reader('https://thredds.met.no/thredds/dodsC/sea/norkyst800m/1h/aggregate_be')
# Out:
# 21:15:14 INFO    opendrift.models.basemodel:532: OpenDriftSimulation initialised (version 1.10.6 / v1.10.6-8-g8b4ee8b-dirty)
# 21:15:14 INFO    opendrift.models.basemodel:532: OpenDriftSimulation initialised (version 1.10.6 / v1.10.6-8-g8b4ee8b-dirty)
# 21:15:14 INFO    opendrift.models.basemodel:532: OpenDriftSimulation initialised (version 1.10.6 / v1.10.6-8-g8b4ee8b-dirty)
# 21:15:14 INFO    opendrift.readers.reader_netCDF_CF_generic:138: Opening dataset: https://thredds.met.no/thredds/dodsC/sea/norkyst800m/1h/aggregate_be

# %%
# Initial position
ini_lat = 59.0
ini_lon = 10.6

# Number of particles and their depth distribution
N = 5
zvec = np.linspace(0, -2.5, N)

# %%
# First simulation: no effect of turbulent mixing, 
# i.e. constant depth for all particles throughout.

# Add readers for input data
o1.add_reader([norkyst])

# Configurations
o1.set_config('drift:vertical_mixing', False)

# Initialize and run
o1.seed_elements(lon=ini_lon, lat=ini_lat, radius=0, number=N,
                z=zvec, time=datetime.utcnow(), wind_drift_factor=0.0, terminal_velocity=0.0)
o1.run(duration=timedelta(hours=24), time_step=600)
# Out:
# 21:15:17 INFO    opendrift.models.basemodel:2579: Fallback values will be used for the following variables which have no readers:
# 21:15:17 INFO    opendrift.models.basemodel:2582: 	ocean_vertical_diffusivity: 0.000000
# 21:15:17 INFO    opendrift.models.basemodel:2582: 	sea_surface_wave_significant_height: 0.000000
# 21:15:17 INFO    opendrift.models.basemodel:2582: 	sea_surface_wave_stokes_drift_x_velocity: 0.000000
# 21:15:17 INFO    opendrift.models.basemodel:2582: 	sea_surface_wave_stokes_drift_y_velocity: 0.000000
# 21:15:17 INFO    opendrift.models.basemodel:2582: 	sea_surface_wave_period_at_variance_spectral_density_maximum: 0.000000
# 21:15:17 INFO    opendrift.models.basemodel:2582: 	sea_surface_wave_mean_period_from_variance_spectral_density_second_frequency_moment: 0.000000
# 21:15:17 INFO    opendrift.models.basemodel:2582: 	surface_downward_x_stress: 0.000000
# 21:15:17 INFO    opendrift.models.basemodel:2582: 	surface_downward_y_stress: 0.000000
# 21:15:17 INFO    opendrift.models.basemodel:2582: 	turbulent_kinetic_energy: 0.000000
# 21:15:17 INFO    opendrift.models.basemodel:2582: 	turbulent_generic_length_scale: 0.000000
# 21:15:17 INFO    opendrift.models.basemodel:2582: 	ocean_mixed_layer_thickness: 50.000000
# 21:15:17 INFO    opendrift.models.basemodel:2741: Adding a dynamical landmask with max. priority based on assumed maximum speed of 1 m/s. Adding a customised landmask may be faster...
# 21:15:17 INFO    opendrift.models.basemodel:1689: Using existing reader for land_binary_mask
# 21:15:17 INFO    opendrift.models.basemodel:1701: All points are in ocean
# 21:15:17 INFO    opendrift.models.basemodel:2870: 2023-09-13 19:15:17.622281 - step 1 of 144 - 5 active elements (0 deactivated)
# 21:15:18 INFO    opendrift.models.basemodel:2870: 2023-09-13 19:25:17.622281 - step 2 of 144 - 5 active elements (0 deactivated)
# 21:15:18 INFO    opendrift.models.basemodel:2870: 2023-09-13 19:35:17.622281 - step 3 of 144 - 5 active elements (0 deactivated)
# 21:15:18 INFO    opendrift.models.basemodel:2870: 2023-09-13 19:45:17.622281 - step 4 of 144 - 5 active elements (0 deactivated)
# 21:15:18 INFO    opendrift.models.basemodel:2870: 2023-09-13 19:55:17.622281 - step 5 of 144 - 5 active elements (0 deactivated)
# 21:15:18 INFO    opendrift.models.basemodel:2870: 2023-09-13 20:05:17.622281 - step 6 of 144 - 5 active elements (0 deactivated)
# 21:15:18 INFO    opendrift.models.basemodel:2870: 2023-09-13 20:15:17.622281 - step 7 of 144 - 5 active elements (0 deactivated)
# 21:15:18 INFO    opendrift.models.basemodel:2870: 2023-09-13 20:25:17.622281 - step 8 of 144 - 5 active elements (0 deactivated)
# 21:15:18 INFO    opendrift.models.basemodel:2870: 2023-09-13 20
of 144 - 5 active elements (0 deactivated)
# 21:15:25 INFO    opendrift.models.basemodel:2870: 2023-09-14 08:55:17.622281 - step 83 of 144 - 5 active elements (0 deactivated)
# 21:15:25 INFO    opendrift.models.basemodel:2870: 2023-09-14 09:05:17.622281 - step 84 of 144 - 5 active elements (0 deactivated)
# 21:15:25 INFO    opendrift.models.basemodel:2870: 2023-09-14 09:15:17.622281 - step 85 of 144 - 5 active elements (0 deactivated)
# 21:15:25 INFO    opendrift.models.basemodel:2870: 2023-09-14 09:25:17.622281 - step 86 of 144 - 5 active elements (0 deactivated)
# 21:15:25 INFO    opendrift.models.basemodel:2870: 2023-09-14 09:35:17.622281 - step 87 of 144 - 5 active elements (0 deactivated)
# 21:15:25 INFO    opendrift.models.basemodel:2870: 2023-09-14 09:45:17.622281 - step 88 of 144 - 5 active elements (0 deactivated)
# 21:15:26 INFO    opendrift.models.basemodel:2870: 2023-09-14 09:55:17.622281 - step 89 of 144 - 5 active elements (0 deactivated)
# 21:15:26 INFO    opendrift.models.basemodel:2870: 2023-09-14 10:05:17.622281 - step 90 of 144 - 5 active elements (0 deactivated)
# 21:15:26 INFO    opendrift.models.basemodel:2870: 2023-09-14 10:15:17.622281 - step 91 of 144 - 5 active elements (0 deactivated)
# 21:15:26 INFO    opendrift.models.basemodel:2870: 2023-09-14 10:25:17.622281 - step 92 of 144 - 5 active elements (0 deactivated)
# 21:15:26 INFO    opendrift.models.basemodel:2870: 2023-09-14 10:35:17.622281 - step 93 of 144 - 5 active elements (0 deactivated)
# 21:15:26 INFO    opendrift.models.basemodel:2870: 2023-09-14 10:45:17.622281 - step 94 of 144 - 5 active elements (0 deactivated)
# 21:15:26 INFO    opendrift.models.basemodel:2870: 2023-09-14 10:55:17.622281 - step 95 of 144 - 5 active elements (0 deactivated)
# 21:15:26 INFO    opendrift.models.basemodel:2870: 2023-09-14 11:05:17.622281 - step 96 of 144 - 5 active elements (0 deactivated)
# 21:15:26 INFO    opendrift.models.basemodel:2870: 2023-09-14 11:15:17.622281 - step 97 of 144 - 5 active elements (0 deactivated)
# 21:15:27 INFO    opendrift.models.basemodel:2870: 2023-09-14 11:25:17.622281 - step 98 of 144 - 5 active elements (0 deactivated)
# 21:15:27 INFO    opendrift.models.basemodel:2870: 2023-09-14 11:35:17.622281 - step 99 of 144 - 5 active elements (0 deactivated)
# 21:15:27 INFO    opendrift.models.basemodel:2870: 2023-09-14 11:45:17.622281 - step 100 of 144 - 5 active elements (0 deactivated)
# 21:15:27 INFO    opendrift.models.basemodel:2870: 2023-09-14 11:55:17.622281 - step 101 of 144 - 5 active elements (0 deactivated)
# 21:15:27 INFO    opendrift.models.basemodel:2870: 2023-09-14 12:05:17.622281 - step 102 of 144 - 5 active elements (0 deactivated)
# 21:15:27 INFO    opendrift.models.basemodel:2870: 2023-09-14 12:15:17.622281 - step 103 of 144 - 5 active elements (0 deactivated)
# 21:15:27 INFO    opendrift.models.basemodel:2870: 2023-09-14 12:25:17.622281 - step 104 of 144 - 5 active elements (0 deactivated)
# 21:15:27 INFO    opendrift.models.basemodel:2870: 2023-09-14 12:35:17.622281 - step 105 of 144 - 5 active elements (0 deactivated)
# 21:15:27 INFO    opendrift.models.basemodel:2870: 2023-09-14 12:45:17.622281 - step 106 of 144 - 5 active elements (0 deactivated)
# 21:15:27 INFO    opendrift.models.basemodel:2870: 2023-09-14 12:55:17.622281 - step 107 of 144 - 5 active elements (0 deactivated)
# 21:15:27 INFO    opendrift.models.basemodel:2870: 2023-09-14 13:05:17.622281 - step 108 of 144 - 5 active elements (0 deactivated)
# 21:15:28 INFO    opendrift.models.basemodel:2870: 2023-09-14 13:15:17.622281 - step 109 of 144 - 5 active elements (0 deactivated)
# 21:15:28 INFO    opendrift.models.basemodel:2870: 2023-09-14 13:25:17.622281 - step 110 of 144 - 5 active elements (0 deactivated)
# 21:15:28 INFO    opendrift.models.basemodel:2870: 2023-09-14 13:35:17.622281 - step 111 of 144 - 5 active elements (0 deactivated)
# 21:15:28 INFO    opendrift.models.basemodel:2870: 2023-09-14 13:45:17.622281 - step 112 of 144 - 5 active elements (0 deactivated)
# 21:15:28 INFO    opendrift.models.basemodel:2870: 2023-09-14 13:55:17.622281 - step 113 of 144 - 5 active elements (0 deactivated)
# 21:15:28 INFO    opendrift.models.basemodel:2870: 2023-09-14 14:05:17.622281 - step 114 of 144 - 5 active elements (0 deactivated)
# 21:15:28 INFO    opendrift.models.basemodel:2870: 2023-09-14 14:15:17.622281 - step 115 of 144 - 5 active elements (0 deactivated)
# 21:15:28 INFO    opendrift.models.basemodel:2870: 2023-09-14 14:25:17.622281 - step 116 of 144 - 5 active elements (0 deactivated)
# 21:15:28 INFO    opendrift.models.basemodel:2870: 2023-09-14 14:35:17.622281 - step 117 of 144 - 5 active elements (0 deactivated)
# 21:15:28 INFO    opendrift.models.basemodel:2870: 2023-09-14 14:45:17.622281 - step 118 of 144 - 5 active elements (0 deactivated)
# 21:15:28 INFO    opendrift.models.basemodel:2870: 2023-09-14 14:55:17.622281 - step 119 of 144 - 5 active elements (0 deactivated)
# 21:15:28 INFO    opendrift.models.basemodel:2870: 2023-09-14 15:05:17.622281 - step 120 of 144 - 5 active elements (0 deactivated)
# 21:15:28 INFO    opendrift.models.basemodel:2870: 2023-09-14 15:15:17.622281 - step 121 of 144 - 5 active elements (0 deactivated)
# 21:15:28 INFO    opendrift.models.basemodel:2870: 2023-09-14 15:25:17.622281 - step 122 of 144 - 5 active elements (0 deactivated)
# 21:15:28 INFO    opendrift.models.basemodel:2870: 2023-09-14 15:35:17.622281 - step 123 of 144 - 5 active elements (0 deactivated)
# 21:15:29 INFO    opendrift.models.basemodel:2870: 2023-09-14 15:45:17.622281 - step 124 of 144 - 5 active elements (0 deactivated)
# 21:15:29 INFO    opendrift.models.basemodel:2870: 2023-09-14 15:55:17.622281 - step 125 of 144 - 5 active elements (0 deactivated)
# 21:15:29 INFO    opendrift.models.basemodel:2870: 2023-09-14 16:05:17.622281 - step 126 of 144 - 5 active elements (0 deactivated)
# 21:15:29 INFO    opendrift.models.basemodel:2870: 2023-09-14 16:15:17.622281 - step 127 of 144 - 5 active elements (0 deactivated)
# 21:15:29 INFO    opendrift.models.basemodel:2870: 2023-09-14 16:25:17.622281 - step 128 of 144 - 5 active elements (0 deactivated)
# 21:15:29 INFO    opendrift.models.basemodel:2870: 2023-09-14 16:35:17.622281 - step 129 of 144 - 5 active elements (0 deactivated)
# 21:15:29 INFO    opendrift.models.basemodel:2870: 2023-09-14 16:45:17.622281 - step 130 of 144 - 5 active elements (0 deactivated)
# 21:15:29 INFO    opendrift.models.basemodel:2870: 2023-09-14 16:55:17.622281 - step 131 of 144 - 5 active elements (0 deactivated)
# 21:15:29 INFO    opendrift.models.basemodel:2870: 2023-09-14 17:05:17.622281 - step 132 of 144 - 5 active elements (0 deactivated)
# 21:15:29 INFO    opendrift.models.basemodel:2870: 2023-09-14 17:15:17.622281 - step 133 of 144 - 5 active elements (0 deactivated)
# 21:15:29 INFO    opendrift.models.basemodel:2870: 2023-09-14 17:25:17.622281 - step 134 of 144 - 5 active elements (0 deactivated)
# 21:15:29 INFO    opendrift.models.basemodel:2870: 2023-09-14 17:35:17.622281 - step 135 of 144 - 5 active elements (0 deactivated)
# 21:15:29 INFO    opendrift.models.basemodel:2870: 2023-09-14 17:45:17.622281 - step 136 of 144 - 5 active elements (0 deactivated)
# 21:15:29 INFO    opendrift.models.basemodel:2870: 2023-09-14 17:55:17.622281 - step 137 of 144 - 5 active elements (0 deactivated)
# 21:15:29 INFO    opendrift.models.basemodel:2870: 2023-09-14 18:05:17.622281 - step 138 of 144 - 5 active elements (0 deactivated)
# 21:15:30 INFO    opendrift.models.basemodel:2870: 2023-09-14 18:15:17.622281 - step 139 of 144 - 5 active elements (0 deactivated)
# 21:15:30 INFO    opendrift.models.basemodel:2870: 2023-09-14 18:25:17.622281 - step 140 of 144 - 5 active elements (0 deactivated)
# 21:15:30 INFO    opendrift.models.basemodel:2870: 2023-09-14 18:35:17.622281 - step 141 of 144 - 5 active elements (0 deactivated)
# 21:15:30 INFO    opendrift.models.basemodel:2870: 2023-09-14 18:45:17.622281 - step 142 of 144 - 5 active elements (0 deactivated)
# 21:15:30 INFO    opendrift.models.basemodel:2870: 2023-09-14 18:55:17.622281 - step 143 of 144 - 5 active elements (0 deactivated)
# 21:15:30 INFO    opendrift.models.basemodel:2870: 2023-09-14 19:05:17.622281 - step 144 of 144 - 5 active elements (0 deactivated)

# %%
# Second simulation: particles are free to move in the vertical, but no buoyancy

# Add readers for input data
o2.add_reader([norkyst])

# Configurations
o2.set_config('drift:vertical_mixing', True)

# Initialize and run
o2.seed_elements(lon=ini_lon, lat=ini_lat, radius=0, number=N,
                z=zvec, time=datetime.utcnow(), wind_drift_factor=0.0, terminal_velocity=0.0)
o2.run(duration=timedelta(hours=24), time_step=600)
# Out:
# 21:15:30 INFO    opendrift.models.basemodel:2579: Fallback values will be used for the following variables which have no readers:
# 21:15:30 INFO    opendrift.models.basemodel:2582: 	ocean_vertical_diffusivity: 0.000000
# 21:15:30 INFO    opendrift.models.basemodel:2582: 	sea_surface_wave_significant_height: 0.000000
# 21:15:30 INFO    opendrift.models.basemodel:2582: 	sea_surface_wave_stokes_drift_x_velocity: 0.000000
# 21:15:30 INFO    opendrift.models.basemodel:2582: 	sea_surface_wave_stokes_drift_y_velocity: 0.000000
# 21:15:30 INFO    opendrift.models.basemodel:2582: 	sea_surface_wave_period_at_variance_spectral_density_maximum: 0.000000
# 21:15:30 INFO    opendrift.models.basemodel:2582: 	sea_surface_wave_mean_period_from_variance_spectral_density_second_frequency_moment: 0.000000
# 21:15:30 INFO    opendrift.models.basemodel:2582: 	surface_downward_x_stress: 0.000000
# 21:15:30 INFO    opendrift.models.basemodel:2582: 	surface_downward_y_stress: 0.000000
# 21:15:30 INFO    opendrift.models.basemodel:2582: 	turbulent_kinetic_energy: 0.000000
# 21:15:30 INFO    opendrift.models.basemodel:2582: 	turbulent_generic_length_scale: 0.000000
# 21:15:30 INFO    opendrift.models.basemodel:2582: 	ocean_mixed_layer_thickness: 50.000000
# 21:15:30 INFO    opendrift.models.basemodel:2741: Adding a dynamical landmask with max. priority based on assumed maximum speed of 1 m/s. Adding a customised landmask may be faster...
# 21:15:30 INFO    opendrift.models.basemodel:1689: Using existing reader for land_binary_mask
# 21:15:30 INFO    opendrift.models.basemodel:1701: All points are in ocean
# 21:15:30 INFO    opendrift.models.basemodel:2870: 2023-09-13 19:15:30.799987 - step 1 of 144 - 5 active elements (0 deactivated)
# 21:15:31 INFO    opendrift.models.basemodel:2870: 2023-09-13 19:25:30.799987 - step 2 of 144 - 5 active elements (0 deactivated)
# 21:15:31 INFO    opendrift.models.basemodel:2870: 2023-09-13 19:35:30.799987 - step 3 of 144 - 5 active elements (0 deactivated)
# 21:15:31 INFO    opendrift.models.basemodel:2870: 2023-09-13 19:45:30.799987 - step 4 of 144 - 5 active elements (0 deactivated)
# 21:15:31 INFO    opendrift.models.basemodel:2870: 2023-09-13 19:55:30.799987 - step 5 of 144 - 5 active elements (0 deactivated)
# 21:15:31 INFO    opendrift.models.basemodel:2870: 2023-09-13 20:05:30.799987 - step 6 of 144 - 5 active elements (0 deactivated)
# 21:15:31 INFO    opendrift.models.basemodel:2870: 2023-09-13 20:15:30.799987 - step 7 of 144 - 5 active elements (0 deactivated)
# 21:15:31 INFO    opendrift.models.basemodel:2870: 2023-09-13 20:25:30.799987 - step 8 of 144 - 5 active elements (0 deactivated)
# 21:15:32 INFO    opendrift.models.basemodel:2870: 2023-09-13 20:35:30.799987 - step 9 of 144 - 5 active elements (0 deactivated)
# 21:15:32 INFO    opendrift.models.basemodel:2870: 2023-09-13 20:45:30.799987 - step 10 of 144 - 5 active elements (0 deactivated)
# 21:15:32 INFO    opendrift.models.basemodel:2870: 2023-09-13 20:55:30.799987 - step 11 of 144 - 5 active elements (0 deactivated)
# 21:15:32 INFO    opendrift.models.basemodel:2870: 2023-09-13 21:05:30.799987 - step 12 of 144 - 5 active elements (0 deactivated)
# 21:15:32 INFO    opendrift.models.basemodel:2870: 2023-09-13 21:15:30.799987 - step 13 of 144 - 5 active elements (0 deactivated)
# 21:15:32 INFO    opendrift.models.basemodel:2870: 2023-09-13 21:25:30.799987 - step 14 of 144 - 5 active elements (0 deactivated)
# 21:15:32 INFO    opendrift.models.basemodel:2870: 2023-09-13 21:35:30.799987 - step 15 of 144 - 5 active elements (0 deactivated)
# 21:15:32 INFO    opendrift.models.basemodel:2870: 2023-09-13 21:45:30.799987 - step 16 of 144 - 5 active elements (0 deactivated)
# 21:15:32 INFO    opendrift.models.basemodel:2870: 2023-09-13 21:55:30.799987 - step 17 of 144 - 5 active elements (0 deactivated)
# 21:15:32 INFO    opendrift.models.basemodel:2870: 2023-09-13 22:05:30.799987 - step 18 of 144 - 5 active elements (0 deactivated)
# 21:15:32 INFO    opendrift.models.basemodel:2870: 2023-09-13 22:15:30.799987 - step 19 of 144 - 5 active elements (0 deactivated)
# 21:15:32 INFO    opendrift.models.basemodel:2870: 2023-09-13 22:25:30.799987 - step 20 of 144 - 5 active elements (0 deactivated)
# 21:15:32 INFO    opendrift.models.basemodel:2870: 2023-09-13 22:35:30.799987 - step 21 of 144 - 5 active elements (0 deactivated)
# 21:15:32 INFO    opendrift.models.basemodel:2870: 2023-09-13 22:45:30.799987 - step 22 of 144 - 5 active elements (0 deactivated)
# 21:15:32 INFO    opendrift.models.basemodel:2870: 2023-09-13 22:55:30.799987 - step 23 of 144 - 5 active elements (0 deactivated)
# 21:15:32 INFO    opendrift.models.basemodel:2870: 2023-09-13 23:05:30.799987 - step 24 of 144 - 5 active elements (0 deactivated)
# 21:15:33 INFO    opendrift.models.basemodel:2870: 2023-09-13 23:15:30.799987 - step 25 of 144 - 5 active elements (0 deactivated)
# 21:15:33 INFO    opendrift.models.basemodel:2870: 2023-09-13 23:25:30.799987 - step 26 of 144 - 5 active elements (0 deactivated)
# 21:15:33 INFO    opendrift.models.basemodel:2870: 2023-09-13 23:35:30.799987 - step 27 of 144 - 5 active elements (0 deactivated)
# 21:15:33 INFO    opendrift.models.basemodel:2870: 2023-09-13 23:45:30.799987 - step 28 of 144 - 5 active elements (0 deactivated)
# 21:15:33 INFO    opendrift.models.basemodel:2870: 2023-09-13 23:55:30.799987 - step 29 of 144 - 5 active elements (0 deactivated)
# 21:15:33 INFO    opendrift.models.basemodel:2870: 2023-09-14 00:05:30.799987 - step 30 of 144 - 5 active elements (0 deactivated)
# 21:15:33 INFO    opendrift.models.basemodel:2870: 2023-09-14 00:15:30.799987 - step 31 of 144 - 5 active elements (0 deactivated)
# 21:15:33 INFO    opendrift.models.basemodel:2870: 2023-09-14 00:25:30.799987 - step 32 of 144 - 5 active elements (0 deactivated)
# 21:15:33 INFO    opendrift.models.basemodel:2870: 2023-09-14 00:35:30.799987 - step 33 of 144 - 5 active elements (0 deactivated)
# 21:15:33 INFO    opendrift.models.basemodel:2870: 2023-09-14 00:45:30.799987 - step 34 of 144 - 5 active elements (0 deactivated)
# 21:15:33 INFO    opendrift.models.basemodel:2870: 2023-09-14 00:55:30.799987 - step 35 of 144 - 5 active elements (0 deactivated)
# 21:15:33 INFO    opendrift.models.basemodel:2870: 2023-09-14 01:05:30.799987 - step 36 of 144 - 5 active elements (0 deactivated)

# %%
# Third simulation: With turbulent mixing (as case 2), 
# and with a terminal rise velocity of a few mm/s.

# Add readers for input data
o3.add_reader([norkyst])

# Configurations
o3.set_config('drift:vertical_mixing', True)

# Initialize and run
o3.seed_elements(lon=ini_lon, lat=ini_lat, radius=0, number=N,
                z=zvec, time=datetime.utcnow(), wind_drift_factor=0.0, terminal_velocity=0.0002)
o3.run(duration=timedelta(hours=24), time_step=600)
# Out:
# 21:13:12 INFO    opendrift.models.basemodel:2579: Fallback values will be used for the following variables which have no readers:
# 21:13:12 INFO    opendrift.models.basemodel:2582: 	ocean_vertical_diffusivity: 0.000000
# 21:13:12 INFO    opendrift.models.basemodel:2582: 	sea_surface_wave_significant_height: 0.000000
# 21:13:12 INFO    opendrift.models.basemodel:2582: 	sea_surface_wave_stokes_drift_x_velocity: 0.000000
# 21:13:12 INFO    opendrift.models.basemodel:2582: 	sea_surface_wave_stokes_drift_y_velocity: 0.000000
# 21:13:12 INFO    opendrift.models.basemodel:2582: 	sea_surface_wave_period_at_variance_spectral_density_maximum: 0.000000
# 21:13:12 INFO    opendrift.models.basemodel:2582: 	sea_surface_wave_mean_period_from_variance_spectral_density_second_frequency_moment: 0.000000
# 21:13:12 INFO    opendrift.models.basemodel:2582: 	surface_downward_x_stress: 0.000000
# 21:13:12 INFO    opendrift.models.basemodel:2582: 	surface_downward_y_stress: 0.000000
# 21:13:12 INFO    opendrift.models.basemodel:2582: 	turbulent_kinetic_energy: 0.000000
# 21:13:12 INFO    opendrift.models.basemodel:2582: 	turbulent_generic_length_scale: 0.000000
# 21:13:12 INFO    opendrift.models.basemodel:2582: 	ocean_mixed_layer_thickness: 50.000000
# 21:13:12 INFO    opendrift.models.basemodel:2741: Adding a dynamical landmask with max. priority based on assumed maximum speed of 1 m/s. Adding a customised landmask may be faster...
# 21:13:12 INFO    opendrift.models.basemodel:1689: Using existing reader for land_binary_mask
# 21:13:12 INFO    opendrift.models.basemodel:1701: All points are in ocean
# 21:13:12 INFO    opendrift.models.basemodel:2870: 2023-09-13 19
of 144 - 5 active elements (0 deactivated)
# 21:13:20 INFO    opendrift.models.basemodel:2870: 2023-09-14 10:13:12.402662 - step 91 of 144 - 5 active elements (0 deactivated)
# 21:13:20 INFO    opendrift.models.basemodel:2870: 2023-09-14 10:23:12.402662 - step 92 of 144 - 5 active elements (0 deactivated)
# 21:13:20 INFO    opendrift.models.basemodel:2870: 2023-09-14 10:33:12.402662 - step 93 of 144 - 5 active elements (0 deactivated)
# 21:13:20 INFO    opendrift.models.basemodel:2870: 2023-09-14 10:43:12.402662 - step 94 of 144 - 5 active elements (0 deactivated)
# 21:13:20 INFO    opendrift.models.basemodel:2870: 2023-09-14 10:53:12.402662 - step 95 of 144 - 5 active elements (0 deactivated)
# 21:13:20 INFO    opendrift.models.basemodel:2870: 2023-09-14 11:03:12.402662 - step 96 of 144 - 5 active elements (0 deactivated)
# 21:13:21 INFO    opendrift.models.basemodel:2870: 2023-09-14 11:13:12.402662 - step 97 of 144 - 5 active elements (0 deactivated)
# 21:13:21 INFO    opendrift.models.basemodel:2870: 2023-09-14 11:23:12.402662 - step 98 of 144 - 5 active elements (0 deactivated)
# 21:13:21 INFO    opendrift.models.basemodel:2870: 2023-09-14 11:33:12.402662 - step 99 of 144 - 5 active elements (0 deactivated)
# 21:13:21 INFO    opendrift.models.basemodel:2870: 2023-09-14 11:43:12.402662 - step 100 of 144 - 5 active elements (0 deactivated)
# 21:13:21 INFO    opendrift.models.basemodel:2870: 2023-09-14 11:53:12.402662 - step 101 of 144 - 5 active elements (0 deactivated)
# 21:13:21 INFO    opendrift.models.basemodel:2870: 2023-09-14 12:03:12.402662 - step 102 of 144 - 5 active elements (0 deactivated)
# 21:13:21 INFO    opendrift.models.basemodel:2870: 2023-09-14 12:13:12.402662 - step 103 of 144 - 5 active elements (0 deactivated)
# 21:13:21 INFO    opendrift.models.basemodel:2870: 2023-09-14 12:23:12.402662 - step 104 of 144 - 5 active elements (0 deactivated)
# 21:13:21 INFO    opendrift.models.basemodel:2870: 2023-09-14 12:33:12.402662 - step 105 of 144 - 5 active elements (0 deactivated)
# 21:13:21 INFO    opendrift.models.basemodel:2870: 2023-09-14 12:43:12.402662 - step 106 of 144 - 5 active elements (0 deactivated)
# 21:13:21 INFO    opendrift.models.basemodel:2870: 2023-09-14 12:53:12.402662 - step 107 of 144 - 5 active elements (0 deactivated)
# 21:13:21 INFO    opendrift.models.basemodel:2870: 2023-09-14 13:03:12.402662 - step 108 of 144 - 5 active elements (0 deactivated)
# 21:13:22 INFO    opendrift.models.basemodel:2870: 2023-09-14 13:13:12.402662 - step 109 of 144 - 5 active elements (0 deactivated)
# 21:13:22 INFO    opendrift.models.basemodel:2870: 2023-09-14 13:23:12.402662 - step 110 of 144 - 5 active elements (0 deactivated)
# 21:13:22 INFO    opendrift.models.basemodel:2870: 2023-09-14 13:33:12.402662 - step 111 of 144 - 5 active elements (0 deactivated)
# 21:13:22 INFO    opendrift.models.basemodel:2870: 2023-09-14 13:43:12.402662 - step 112 of 144 - 5 active elements (0 deactivated)
# 21:13:22 INFO    opendrift.models.basemodel:2870: 2023-09-14 13:53:12.402662 - step 113 of 144 - 5 active elements (0 deactivated)
# 21:13:22 INFO    opendrift.models.basemodel:2870: 2023-09-14 14:03:12.402662 - step 114 of 144 - 5 active elements (0 deactivated)
# 21:13:22 INFO    opendrift.models.basemodel:2870: 2023-09-14 14:13:12.402662 - step 115 of 144 - 5 active elements (0 deactivated)
# 21:13:22 INFO    opendrift.models.basemodel:2870: 2023-09-14 14:23:12.402662 - step 116 of 144 - 5 active elements (0 deactivated)
# 21:13:22 INFO    opendrift.models.basemodel:2870: 2023-09-14 14:33:12.402662 - step 117 of 144 - 5 active elements (0 deactivated)
# 21:13:22 INFO    opendrift.models.basemodel:2870: 2023-09-14 14:43:12.402662 - step 118 of 144 - 5 active elements (0 deactivated)
# 21:13:22 INFO    opendrift.models.basemodel:2870: 2023-09-14 14:53:12.402662 - step 119 of 144 - 5 active elements (0 deactivated)
# 21:13:22 INFO    opendrift.models.basemodel:2870: 2023-09-14 15:03:12.402662 - step 120 of 144 - 5 active elements (0 deactivated)
# 21:13:23 INFO    opendrift.models.basemodel:2870: 2023-09-14 15:13:12.402662 - step 121 of 144 - 5 active elements (0 deactivated)
# 21:13:23 INFO    opendrift.models.basemodel:2870: 2023-09-14 15:23:12.402662 - step 122 of 144 - 5 active elements (0 deactivated)
# 21:13:23 INFO    opendrift.models.basemodel:2870: 2023-09-14 15:33:12.402662 - step 123 of 144 - 5 active elements (0 deactivated)
# 21:13:23 INFO    opendrift.models.basemodel:2870: 2023-09-14 15:43:12.402662 - step 124 of 144 - 5 active elements (0 deactivated)
# 21:13:23 INFO    opendrift.models.basemodel:2870: 2023-09-14 15:53:12.402662 - step 125 of 144 - 5 active elements (0 deactivated)
# 21:13:23 INFO    opendrift.models.basemodel:2870: 2023-09-14 16:03:12.402662 - step 126 of 144 - 5 active elements (0 deactivated)
# 21:13:23 INFO    opendrift.models.basemodel:2870: 2023-09-14 16:13:12.402662 - step 127 of 144 - 5 active elements (0 deactivated)
# 21:13:23 INFO    opendrift.models.basemodel:2870: 2023-09-14 16:23:12.402662 - step 128 of 144 - 5 active elements (0 deactivated)
# 21:13:23 INFO    opendrift.models.basemodel:2870: 2023-09-14 16:33:12.402662 - step 129 of 144 - 5 active elements (0 deactivated)
# 21:13:23 INFO    opendrift.models.basemodel:2870: 2023-09-14 16:43:12.402662 - step 130 of 144 - 5 active elements (0 deactivated)
# 21:13:23 INFO    opendrift.models.basemodel:2870: 2023-09-14 16:53:12.402662 - step 131 of 144 - 5 active elements (0 deactivated)
# 21:13:23 INFO    opendrift.models.basemodel:2870: 2023-09-14 17:03:12.402662 - step 132 of 144 - 5 active elements (0 deactivated)
# 21:13:24 INFO    opendrift.models.basemodel:2870: 2023-09-14 17:13:12.402662 - step 133 of 144 - 5 active elements (0 deactivated)
# 21:13:24 INFO    opendrift.models.basemodel:2870: 2023-09-14 17:23:12.402662 - step 134 of 144 - 5 active elements (0 deactivated)
# 21:13:24 INFO    opendrift.models.basemodel:2870: 2023-09-14 17:33:12.402662 - step 135 of 144 - 5 active elements (0 deactivated)
# 21:13:24 INFO    opendrift.models.basemodel:2870: 2023-09-14 17:43:12.402662 - step 136 of 144 - 5 active elements (0 deactivated)
# 21:13:24 INFO    opendrift.models.basemodel:2870: 2023-09-14 17:53:12.402662 - step 137 of 144 - 5 active elements (0 deactivated)
# 21:13:24 INFO    opendrift.models.basemodel:2870: 2023-09-14 18:03:12.402662 - step 138 of 144 - 5 active elements (0 deactivated)
# 21:13:24 INFO    opendrift.models.basemodel:2870: 2023-09-14 18:13:12.402662 - step 139 of 144 - 5 active elements (0 deactivated)
# 21:13:24 INFO    opendrift.models.basemodel:2870: 2023-09-14 18:23:12.402662 - step 140 of 144 - 5 active elements (0 deactivated)
# 21:13:24 INFO    opendrift.models.basemodel:2870: 2023-09-14 18:33:12.402662 - step 141 of 144 - 5 active elements (0 deactivated)
# 21:13:24 INFO    opendrift.models.basemodel:2870: 2023-09-14 18:43:12.402662 - step 142 of 144 - 5 active elements (0 deactivated)
# 21:13:24 INFO    opendrift.models.basemodel:2870: 2023-09-14 18:53:12.402662 - step 143 of 144 - 5 active elements (0 deactivated)
# 21:13:24 INFO    opendrift.models.basemodel:2870: 2023-09-14 19:03:12.402662 - step 144 of 144 - 5 active elements (0 deactivated)

# %%
# Plot differences between case 1 and 2:
o1.plot(compare=o2, fast=True, legend=['Constant depth', 'With vertical mixing'])
# Out:
# 21:13:25 WARNING opendrift.models.basemodel:3214: Plotting fast. This will make your plots less accurate.
# (<GeoAxes: title={'center': 'OpenDrift - OceanDrift\n2023-09-13 19:12 to 2023-09-14 19:12 UTC (145 steps)'}>,
#  <Figure size 1100x1059.31 with 1 Axes>)

# %%
# Plot differences between case 2 and 3:
o2.plot(compare=o3, fast=True, legend=['No buoyancy', 'With rise velocity'])
# Out:
# 21:13:26 WARNING opendrift.models.basemodel:3214: Plotting fast. This will make your plots less accurate.
# (<GeoAxes: title={'center': 'OpenDrift - OceanDrift\n2023-09-13 19:12 to 2023-09-14 19:12 UTC (145 steps)'}>,
#  <Figure size 1047.58x1100 with 1 Axes>)

# %%
# Plot background currents
o1.plot(fast=True, background=['x_sea_water_velocity', 'y_sea_water_velocity'])
# Out:
# 21:13:26 WARNING opendrift.models.basemodel:3214: Plotting fast. This will make your plots less accurate.
# (<GeoAxes: title={'center': 'OpenDrift - OceanDrift\n2023-09-13 19:12 to 2023-09-14 19:12 UTC (145 steps)'}>,
#  <Figure size 1092.27x1100 with 2 Axes>)
